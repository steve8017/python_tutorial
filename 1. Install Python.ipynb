# %% [markdown]
# It is now in Apri 2018.
#
# Start with python3 instead of python 2. Python3 is more popular than python2. End of debate.
#
# Go to this official python page: https://www.python.org/downloads/ and click "Download Python 3.6.5 button". See the picture below.

# %%
# Please ignore the following two lines of code for now. Will explain it later soon.
from IPython.display import Image
Image(filename='img/download_python.png')

# %% [markdown]
# On Windows 10/7, you can just double click the downloaded file with the defaul setting to install python.
#
# [For FedEx employees, admin priviledge is removed by default. So you need to call that 800 number to get a temporary admin permission to install python]
