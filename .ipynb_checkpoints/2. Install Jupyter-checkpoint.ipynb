# %% [markdown]
# Now we have python (some minimum package with a python interpreter) installed on Windows 10/7 on our local machine. It is time to install other (third party) python packages to release the full power of this platform.
#
# We will use pip to do that. pip is a package management system used to install and manage software packages written in Python. pip comes with python3.

# %% [markdown]
# In short **jupyter notebook** is the most popular platform these years to do data scicence if you are younger (or data analysis if you are older). First, we need to download it using pip.
#
# Open a windows console as before.
#
# *If you are FedEx employee who is on the intranet, you have to set the proxy server first
# as follows in the windows console:*
#
# *set http_proxy=http://internet.proxy.fedex.com:3128*
#
# *set https_proxy=https://internet.proxy.fedex.com:3128*
#
# *If you are regular user who is on the web directly, ignore the commands above.*
#
# type
#
# pip install jupyter

# %%
# Please ignore the following two lines of code for now. Will explain it later soon.
from IPython.display import Image
Image(filename='img/install_jupyter.png')

# %% [markdown]
# If you don't see error message at this point, you probably are good.
#
# Now try to launch jupyter notebook as follows in the same windows console:

# %%
# Please ignore this line, for now, which actually loads an image to this page.
Image(filename='img/run_jupyter_notebook.png')

# %% [markdown]
# The command above will launch a web browser to show you something similar to the web page below. It should be a blank page on your browser. The image I show here has some scripts already on my browser.

# %%
Image(filename='img/first_jupyter_page.png')

# %% [markdown]
# Congratulations. We now have set up the most popular platform for data science - jupyter notebook with python!
